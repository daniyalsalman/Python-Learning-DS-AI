# %%
import pandas as pd

df= pd.read_csv("../datasets/nhanes_2015_2016.csv")

# %%
df.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1       2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2       1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 3       1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4       1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# ...

# %%
df
# Out:
#        SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0     83732     1.0     NaN     1.0       1         1        62         3
# 1     83733     1.0     NaN     6.0       1         1        53         3
# 2     83734     1.0     NaN     NaN       1         1        78         3
# 3     83735     2.0     1.0     1.0       2         2        56         3
# 4     83736     2.0     1.0     1.0       2         2        42         4
# ...     ...     ...     ...     ...     ...       ...       ...       ...
# 5730  93695     2.0     2.0     NaN       1         2        76         3
# 5731  93696     2.0     2.0     NaN       2         1        26         3
# 5732  93697     1.0     NaN     1.0       1         2        80         3
# 5733  93700     NaN     NaN     NaN       1         1        35         3
# 5734  93702     1.0     NaN     2.0       2         2        24         3
#
#       DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# ...

# %%
df.tail(10)
# Out:
#        SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 5725  93684     2.0     2.0     NaN       2         1        34         4
# 5726  93685     1.0     NaN     2.0       1         1        53         1
# 5727  93689     2.0     1.0     NaN       2         2        69         1
# 5728  93690     1.0     NaN     3.0       2         1        32         2
# 5729  93691     2.0     2.0     NaN       2         1        25         5
# 5730  93695     2.0     2.0     NaN       1         2        76         3
# 5731  93696     2.0     2.0     NaN       2         1        26         3
# 5732  93697     1.0     NaN     1.0       1         2        80         3
# 5733  93700     NaN     NaN     NaN       1         1        35         3
# 5734  93702     1.0     NaN     2.0       2         2        24         3
#
#       DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 5725       1.0       5.0  ...   112.0    72.0  101.2  180.9    30.9    43.7
# ...

# %%
df.shape
# Out:
# (5735, 28)

# %%
df['BMXWT']
# Out:
# 0        94.8
# 1        90.4
# 2        83.4
# 3       109.8
# 4        55.2
#         ...
# 5730     59.1
# 5731    112.1
# 5732     71.7
# 5733     78.2
# 5734     58.3
# Name: BMXWT, Length: 5735, dtype: float64

# %%
y=[6,7,10,11,12,3,4]

import matplotlib 
import matplotlib.pyplot as plt 
# %matplotlib inline

plt.plot(y)
plt.show()

# %%
x=[1,2,3,4,5,6,7]
plt.figure(figsize=(2,5))
plt.plot(x,y)

plt.title("Visualization #1")
plt.xlabel("x values")
plt.ylabel("y values")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20,6))

x=range(df['BMXWT'].size)
y=df['BMXWT']

plt.scatter(x,y,marker='x',s=0.1)

plt.title("NHANES 2015-2016 Dataset(weights)")
plt.xlabel("IDs of people")
plt.ylabel("Weights")
# Out:
# Text(0, 0.5, 'Weights')

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y,s=2.7)

# %%
plt.plot(x,y,scalex=1.01)
# plt.scatter(x,y)

# %%
plt.scatter(x,y,colorizer="alpha=2.6")

# %%
plt.scatter(x,y,vmin=0.5)
# Out:
# C:\Users\daniy\AppData\Local\Temp\ipykernel_10868\2922010397.py:1: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin' will be ignored
#   plt.scatter(x,y,vmin=0.5)

# %%
sum(y)/len(x)
# Out:
# nan

# %%
y=y.dropna()

# %%
sum(y)/len(y)
# Out:
# 81.34267560889516

# %%
df['BMXWT'].mean()
# Out:
# np.float64(81.34267560889516)

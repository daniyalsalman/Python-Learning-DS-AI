# %%
import matplotlib 
import matplotlib.pyplot as plt
# %matplotlib inline 
import numpy as np

# %%
import pandas as pd 
df=pd.read_csv("../datasets/nhanes_2015_2016.csv")

# %%
gender=df['RIAGENDR']
gender.value_counts()
# Out:
# RIAGENDR
# 2    2976
# 1    2759
# Name: count, dtype: int64

# %%
gender.value_counts().plot(kind="bar")
plt.show()

# %%
gender.value_counts().plot(kind="bar")
plt.xlabel("Gender")
plt.ylabel("Frequencies")
plt.xticks([0,1],['Female','Male'])
plt.show()

# %%
shirt_sizes=np.array([22,23,24,25,26,37,46,89,12,45,98])
shirt_sizes.mean()
# Out:
# np.float64(40.63636363636363)

# %%
from collections import Counter
count=Counter()

for one_size in shirt_sizes:
    count[one_size]+=1

count.most_common()
# Out:
# [(np.int64(22), 1),
#  (np.int64(23), 1),
#  (np.int64(24), 1),
#  (np.int64(25), 1),
#  (np.int64(26), 1),
#  (np.int64(37), 1),
#  (np.int64(46), 1),
#  (np.int64(89), 1),
#  (np.int64(12), 1),
#  (np.int64(45), 1),
#  (np.int64(98), 1)]

# %%
# %pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from scipy import stats
stats.mode(shirt_sizes)
# Out:
# ModeResult(mode=np.int64(12), count=np.int64(1))

# %%
gender.mode()
# Out:
# 0    2
# Name: RIAGENDR, dtype: int64

# %%
df['HIQ210'].unique()
# Out:
# array([ 2., nan,  1.,  9.])

# %%
df['HIQ210'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='HIQ210'>

# %%
df['HIQ210'].value_counts().plot(kind="pie")
# Out:
# <Axes: >

# %%
weight=df['BMXWT']
print(type(weight))

weight.value_counts().plot(kind="bar")
plt.show()
# Out:
# <class 'pandas.Series'>
# <Axes: xlabel='BMXWT'>

# %%
weight.hist(bins=2)
# Out:
# <Axes: >

# %%
weight.hist(bins=3)
# Out:
# <Axes: >

# %%
weight.hist(bins=100)
# Out:
# <Axes: >

# %%
weight.hist(bins=30)
# Out:
# <Axes: >

# %%
plt.hist(weight,bins=20)
plt.ylabel("frequency")
plt.xlabel("Weights")
plt.title("histogram using matplotlib of weights from the nhanes dataset")
# Out:
# Text(0.5, 1.0, 'histogram using matplotlib of weights from the nhanes dataset')

# %%
import seaborn as sns

# %%
sns.set_color_codes(palette="deep")

# %%
sns.set_style("darkgrid")

# %%
sns.displot(weight,bins=20)
plt.ylabel("Frequency")
plt.xlabel("Weights")
plt.title("seaborn plotting with mpl combined ")
sns.despine(offset=20,trim=True)

# %%
plt.figure(figsize=(20,10))
x=range(df['BMXWT'].size)
y=df['BMXWT']

plt.scatter(x,y,marker='X',s=1)

# %%
plt.figure(figsize=(20,10))
x=range(df['BMXWT'].size)
y=df['BMXWT']

plt.scatter(x,y,marker='X',s=0.5)
plt.title("weights again 😭😭")
plt.xlabel("id of person")
plt.ylabel("weight(kg)")
p1=(0,75)
p2=(6000,75)

x_c,y_c=zip(p1,p2)
plt.plot(x_c,y_c, color='red',linewidth=0.75)

x_c,y_c=([0,6000],[weight.mean(),weight.mean()])
plt.plot(x_c,y_c, color='yellow', linewidth=2)
# Out:
# c:\Python Learning DS AI\venv\Lib\site-packages\IPython\core\events.py:96: UserWarning: Glyph 128557 (\N{LOUDLY CRYING FACE}) missing from font(s) Arial.
#   func(*args, **kwargs)
# c:\Python Learning DS AI\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128557 (\N{LOUDLY CRYING FACE}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
weight.max()
# Out:
# np.float64(198.9)

# %%
weight.min()
# Out:
# np.float64(32.4)

# %%
weight.median()
# Out:
# np.float64(78.2)

# %%
weight.mean()
# Out:
# np.float64(81.34267560889516)

# %%
male_weight=df.loc[df['RIAGENDR']==2,'BMXWT']

# %%
female_weight=df.loc[df['RIAGENDR']==1,'BMXWT']

# %%
plt.Figure(figsize=(4,8))

# %%
sns.set_style("darkgrid")
ax=sns.boxplot(x="RIAGENDR",y="BMXWT",data=df,palette="Set3")
# Out:
# C:\Users\daniy\AppData\Local\Temp\ipykernel_9260\3124020256.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.boxplot(x="RIAGENDR",y="BMXWT",data=df,palette="Set3")

# %%
# male_weight.mean()
female_weight.mean()
# Out:
# np.float64(86.57326222876058)

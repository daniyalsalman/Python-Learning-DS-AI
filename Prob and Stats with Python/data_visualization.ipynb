# %%
y=[6,7,10,11,12,3,4]

# %%
import matplotlib 
import matplotlib.pyplot as plt 
# %matplotlib inline

plt.plot(y)
plt.show()

# %%
x=[1,2,3,4,5,6,7]
plt.figure(figsize=(2,5))
plt.plot(x,y)

plt.title("Visualization #1")
plt.xlabel("x values")
plt.ylabel("y values")
plt.grid()
plt.show()

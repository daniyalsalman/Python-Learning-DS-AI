# %%
import pandas as pd

df=pd.read_excel("../datasets/titanic.xlsx")

# %%
list_of_genders=[df['sex']]

# %%
x={'categorical': list_of_genders}

# %%
ab=pd.DataFrame(x)

# %%
dummy_data=pd.get_dummies(df['sex'],prefix='sex')

# %%
dummy_data
# Out:
#      sex_female  sex_male
# 0         False      True
# 1          True     False
# 2          True     False
# 3          True     False
# 4         False      True
# ..          ...       ...
# 886       False      True
# 887        True     False
# 888        True     False
# 889       False      True
# 890       False      True
#
# [891 rows x 2 columns]

# %%
dummy_data.head
# Out:
# <bound method NDFrame.head of      sex_female  sex_male
# 0         False      True
# 1          True     False
# 2          True     False
# 3          True     False
# 4         False      True
# ..          ...       ...
# 886       False      True
# 887        True     False
# 888        True     False
# 889       False      True
# 890       False      True
#
# [891 rows x 2 columns]>

# %%
dummy_data.values
# Out:
# array([[False,  True],
#        [ True, False],
#        [ True, False],
#        ...,
#        [ True, False],
#        [False,  True],
#        [False,  True]], shape=(891, 2))

# %%
dummy_data.tail(20)
# Out:
#      sex_female  sex_male
# 871        True     False
# 872       False      True
# 873       False      True
# 874        True     False
# 875        True     False
# 876       False      True
# 877       False      True
# 878       False      True
# 879        True     False
# 880        True     False
# 881       False      True
# 882        True     False
# 883       False      True
# 884       False      True
# 885        True     False
# 886       False      True
# 887        True     False
# 888        True     False
# 889       False      True
# 890       False      True

# %%
# the female vector is 1,0
# male vector is 0,1
